# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import math

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from tensorflow import set_random_seed
# for reproducibility 
np.random.seed(1)
set_random_seed(1)

from keras.layers import Dense, Input, concatenate
from keras.layers import Conv2D, MaxPooling2D, Flatten, Lambda, Dropout, Activation, Lambda
from keras.layers import Reshape, Conv2DTranspose
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.datasets import mnist
from keras.datasets import fashion_mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K

from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils

from sklearn.model_selection import train_test_split

# %%
# Multi-input classifier - Rectangle outlier samples

class Classifier:

    # 3 Class classifier - class 2 represents outliers and class 0,1 represent inliers.
    # Class 0 sampled from a circle centered at (x, y) = (-2, 0) with radius 0.5
    # Class 1 sampled from a circle centered at (x, y) = (+2, 0) with radius 0.5
    # Class 2 sampled from rectagle with origin (x, y) = (-3, -1) with h=2, w=6 excluding regions covered by inliers.

    # Generate n points uniformly within a circle of radius r, centered at (x, y)
    # return as a numpy array n x 2 of dtype = float32
    def __init__(self):
        self.number_of_classes = 2
        self.input_dim = 2
        self.epochs = 200
        self.batch_size = 32
        # There are 2 inlier circles
        # Inlier circle centers on the 1st axis; for all other dimensions, the centers are at 0.
        self.x1 = -10
        self.x2 = +10
        self.r = 5
        # Number of inlier samples for each class
        self.n = 1000
        # width of the outlier outer square side
        self.s = 100

        self.data, self.labels, self.data_out, self.labels_out = self.get_data()
        print(self.data.shape, self.labels.shape)
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.data, self.labels, test_size=0.5, shuffle=True, stratify=self.labels,
                                                            random_state=1)
        self.X_train_outliers, self.X_test_outliers, self.y_train_outliers, self.y_test_outliers = train_test_split(self.data_out, self.labels_out, test_size=0.5, shuffle=True,
                                                            random_state=1)
        self.multi_input_classifier, self.model = self.get_model()

        self.mu = np.mean(np.concatenate((self.X_train, self.X_train_outliers), axis=0), axis=0)
        self.sigma = np.std(np.concatenate((self.X_train, self.X_train_outliers), axis=0), axis=0)

        self.data = self.preprocess_data(self.data)
        self.data_out = self.preprocess_data(self.data_out)
        self.X_train = self.preprocess_data(self.X_train)
        self.X_test = self.preprocess_data(self.X_test)
        self.X_train_outlier = self.preprocess_data(self.X_train_outliers)
        self.X_test_outliers = self.preprocess_data(self.X_test_outliers)


    # return True if point p (a list) lies inside a hypersphere centered at the origin with radius r
    def is_in_hypersphere(self, r, p):
        p = np.array(p)
        return np.sum(p*p) <= r**2


    # return True if point p (a list) lies inside a hypersphere centered at the (x, 0, 0, ...) with radius r
    def is_in_hypersphere_centered_at(self, x, r, p):
        p = np.array(p)
        p[0] -= x
        return np.sum(p*p) <= r**2


    # uniformly sample a point from a square centered at the origin with side = s
    def sample_point_from_square(self, s):
        p = []
        # first point
        for i in range(0, self.input_dim):
            p.append(np.random.uniform(-1*s/2, s/2, 1))
        return p


    # sample points using rejection sampling from a sphere centered at the origin
    def sample_point_from_hypersphere(self, r):
        p = self.sample_point_from_square(2*r)
        while not self.is_in_hypersphere(r, p):
            p = self.sample_point_from_square(2*r)
        return p


    def preprocess_data(self, x):
        #return (x-self.mu)/self.sigma
        return x

    # sample from a hypersphre with rejection sampling
    def get_hypersphere_data(self, x, r, n):
        data = np.zeros((n, self.input_dim))
        count = 0
        while count<n:
            data[count, :] = self.sample_point_from_hypersphere(r)
            # update the point with offset for the 1st dimension
            data[count, 0] += x
            count += 1

        data = data.astype(np.float32)
        return data
        # plt.scatter(x, y, s = 4)
    

    # generate n outlier points uniformly sampled within square centered at the origin
    # with side=s, excuding the inlier circles
    def get_outlier_data_sub(self, s, x1, x2, r, n):
        count = 0
        data = np.zeros((n, self.input_dim))
        while count < n:
            p = self.sample_point_from_square(s)
            if (not self.is_in_hypersphere_centered_at(x1, r, p)) and (not self.is_in_hypersphere_centered_at(x2, r, p)):
                data[count, :] = p
                count += 1
        return data

    def get_outlier_data(self):
        data = self.get_outlier_data_sub(self.s, self.x1, self.x2, self.r+0.3, 2*self.n)
        return data.astype(np.float32)

        
    def get_data(self):
        # class 0 data
        data = self.get_hypersphere_data(self.x1, self.r, self.n)
        labels = np.ones((self.n, 1))*0
        print(labels.shape)
        # class 1 data
        data = np.concatenate((data, self.get_hypersphere_data(self.x2, self.r, self.n)), axis=0)
        labels = np.concatenate((labels, np.ones((self.n, 1))*1), axis=0)
        print(labels.shape)
        # outlier data
        data_out = self.get_outlier_data()
        labels_out = np.ones((2*self.n,1))*2
        print(labels.shape)
        return data.astype(np.float32), labels.astype(np.float32), data_out.astype(np.float32), labels_out.astype(np.float32)

    
    def base_model(self):
        model = Sequential()
        model.add(Dense(500, input_shape=(self.input_dim,)))
        model.add(Activation('relu'))
        model.add(Dense(500))
        model.add(Activation('relu'))
        model.add(Dense(self.number_of_classes))
        # model.add(Convolution2D(10,3,3, border_mode='same'))
        # model.add(GlobalAveragePooling2D())
        model.add(Activation('softmax'))
        #model.compile(loss='binary_crossentropy', optimizer=Adam(0.001), metrics=['accuracy'])
        return model

    def get_model(self):
        # instantiate classifier model
        classifier = self.base_model()
        classifier.compile(loss='categorical_crossentropy', optimizer=Adam(0.001))

        # just the classifier
        input_data = Input(shape=(self.input_dim, ))
        y_classifier = classifier(input_data)


        # 2 input classifier
        input_a = Input(shape=(self.input_dim, ))
        processed_a = classifier(input_a)
        input_b = Input(shape=(self.input_dim, ))
        processed_b = classifier(input_b)

        out_a = Lambda(lambda x: x, name = 'out_a')(processed_a)
        out_b = Lambda(lambda x: x, name = 'out_b')(processed_b)

        multi_input_classifier = Model(inputs=[input_a, input_b], outputs=[out_a, out_b])
        multi_input_classifier.compile(loss={'out_a':'categorical_crossentropy', 'out_b':'categorical_crossentropy'}, 
                                       loss_weights={'out_a': 1.0, 'out_b': 1.0}, optimizer=Adam(0.001), 
                                       metrics={'out_a':['acc'], 'out_b':['categorical_crossentropy']})


        mnist_model = Model(input_data, y_classifier)
        mnist_model.compile(loss='categorical_crossentropy', optimizer=Adam(0.001), metrics=['acc'])

        return multi_input_classifier, mnist_model


    def train(self):
        # fit the model
        Y_train = np_utils.to_categorical(self.y_train, self.number_of_classes)
        Y_train_outliers = np.ones((self.y_train_outliers.shape[0], self.number_of_classes))
        Y_test = np_utils.to_categorical(self.y_test, self.number_of_classes)
        Y_test_outliers = np.ones((self.y_test_outliers.shape[0], self.number_of_classes))

        self.multi_input_classifier.fit([self.X_train, self.X_train_outliers], [Y_train, Y_train_outliers], 
                                        epochs=self.epochs, validation_data=([self.X_test, self.X_test_outliers], [Y_test, Y_test_outliers]), batch_size=self.batch_size)

# %%
classifier = Classifier()

classifier.train()
# Out:
# (1000, 1)
# (2000, 1)
# (2000, 1)
# ((2000, 2), (2000, 1))
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/200
# 1000/1000 [==============================] - 0s 432us/step - loss: 2.9572 - out_a_loss: 0.5504 - out_b_loss: 2.4068 - out_a_acc: 0.8080 - out_b_categorical_crossentropy: 2.4068 - val_loss: 2.2165 - val_out_a_loss: 0.4324 - val_out_b_loss: 1.7842 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.7842
# Epoch 2/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 2.1248 - out_a_loss: 0.4678 - out_b_loss: 1.6571 - out_a_acc: 0.9590 - out_b_categorical_crossentropy: 1.6571 - val_loss: 1.9130 - val_out_a_loss: 0.4706 - val_out_b_loss: 1.4424 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4424
# Epoch 3/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.8931 - out_a_loss: 0.4181 - out_b_loss: 1.4751 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4751 - val_loss: 1.8306 - val_out_a_loss: 0.3838 - val_out_b_loss: 1.4468 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4468
# Epoch 4/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.7813 - out_a_loss: 0.3391 - out_b_loss: 1.4422 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4422 - val_loss: 1.7265 - val_out_a_loss: 0.2708 - val_out_b_loss: 1.4557 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4557
# Epoch 5/200
# 1000/1000 [==============================] - 0s 96us/step - loss: 1.6903 - out_a_loss: 0.2395 - out_b_loss: 1.4508 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4508 - val_loss: 1.6722 - val_out_a_loss: 0.2128 - val_out_b_loss: 1.4594 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4594
# Epoch 6/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.6167 - out_a_loss: 0.1629 - out_b_loss: 1.4538 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4538 - val_loss: 1.5925 - val_out_a_loss: 0.1214 - val_out_b_loss: 1.4711 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4711
# Epoch 7/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.5752 - out_a_loss: 0.1130 - out_b_loss: 1.4621 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4621 - val_loss: 1.5744 - val_out_a_loss: 0.1033 - val_out_b_loss: 1.4711 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4711
# Epoch 8/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.5683 - out_a_loss: 0.0884 - out_b_loss: 1.4799 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4799 - val_loss: 1.5548 - val_out_a_loss: 0.0784 - val_out_b_loss: 1.4764 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4764
# Epoch 9/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.5602 - out_a_loss: 0.0756 - out_b_loss: 1.4846 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4846 - val_loss: 1.6603 - val_out_a_loss: 0.0736 - val_out_b_loss: 1.5868 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.5868
# Epoch 10/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.5731 - out_a_loss: 0.0711 - out_b_loss: 1.5020 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.5020 - val_loss: 1.5441 - val_out_a_loss: 0.0670 - val_out_b_loss: 1.4772 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4772
# Epoch 11/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.5421 - out_a_loss: 0.0608 - out_b_loss: 1.4813 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4813 - val_loss: 1.5693 - val_out_a_loss: 0.0506 - val_out_b_loss: 1.5188 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.5188
# Epoch 12/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.5194 - out_a_loss: 0.0519 - out_b_loss: 1.4675 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4675 - val_loss: 1.5541 - val_out_a_loss: 0.0644 - val_out_b_loss: 1.4897 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4897
# Epoch 13/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1
- out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4002 - val_loss: 1.4307 - val_out_a_loss: 0.0036 - val_out_b_loss: 1.4271 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4271
# Epoch 45/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.4086 - out_a_loss: 0.0087 - out_b_loss: 1.3999 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3999 - val_loss: 1.4171 - val_out_a_loss: 0.0079 - val_out_b_loss: 1.4092 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4092
# Epoch 46/200
# 1000/1000 [==============================] - 0s 96us/step - loss: 1.4097 - out_a_loss: 0.0106 - out_b_loss: 1.3991 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3991 - val_loss: 1.4206 - val_out_a_loss: 0.0096 - val_out_b_loss: 1.4110 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4110
# Epoch 47/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4106 - out_a_loss: 0.0078 - out_b_loss: 1.4029 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4029 - val_loss: 1.4219 - val_out_a_loss: 0.0060 - val_out_b_loss: 1.4159 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4159
# Epoch 48/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4060 - out_a_loss: 0.0075 - out_b_loss: 1.3984 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3984 - val_loss: 1.4169 - val_out_a_loss: 0.0141 - val_out_b_loss: 1.4027 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4027
# Epoch 49/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.4075 - out_a_loss: 0.0093 - out_b_loss: 1.3983 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3983 - val_loss: 1.4237 - val_out_a_loss: 0.0197 - val_out_b_loss: 1.4040 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4040
# Epoch 50/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.4104 - out_a_loss: 0.0102 - out_b_loss: 1.4003 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4003 - val_loss: 1.4270 - val_out_a_loss: 0.0135 - val_out_b_loss: 1.4134 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4134
# Epoch 51/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.4142 - out_a_loss: 0.0125 - out_b_loss: 1.4016 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4016 - val_loss: 1.4165 - val_out_a_loss: 0.0070 - val_out_b_loss: 1.4096 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4096
# Epoch 52/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4075 - out_a_loss: 0.0083 - out_b_loss: 1.3992 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3992 - val_loss: 1.4186 - val_out_a_loss: 0.0057 - val_out_b_loss: 1.4129 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4129
# Epoch 53/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4052 - out_a_loss: 0.0072 - out_b_loss: 1.3980 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3980 - val_loss: 1.4183 - val_out_a_loss: 0.0064 - val_out_b_loss: 1.4119 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4119
# Epoch 54/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.4039 - out_a_loss: 0.0073 - out_b_loss: 1.3966 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3966 - val_loss: 1.4266 - val_out_a_loss: 0.0064 - val_out_b_loss: 1.4202 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4202
# Epoch 55/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4038 - out_a_loss: 0.0068 - out_b_loss: 1.3970 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3970 - val_loss: 1.4196 - val_out_a_loss: 0.0111 - val_out_b_loss: 1.4084 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4084
# Epoch 56/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.4049 - out_a_loss: 0.0072 - out_b_loss: 1.3977 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3977 - val_loss: 1.4203 - val_out_a_loss: 0.0178 - val_out_b_loss: 1.4025 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4025
# Epoch 57/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.4046 - out_a_loss: 0.0090 - out_b_loss: 1.3957 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3957 - val_loss: 1.4361 - val_out_a_loss: 0.0106 - val_out_b_loss: 1.4254 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4254
# Epoch 58/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4093 - out_a_loss: 0.0080 - out_b_loss: 1.4014 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4014 - val_loss: 1.4136 - val_out_a_loss: 0.0062 - val_out_b_loss: 1.4074 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4074
# Epoch 59/200
# 1000/1000 [==============================] - 0s 102us/step - loss: 1.4017 - out_a_loss: 0.0053 - out_b_loss: 1.3964 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3964 - val_loss: 1.4135 - val_out_a_loss: 0.0092 - val_out_b_loss: 1.4043 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4043
# Epoch 60/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.4133 - out_a_loss: 0.0144 - out_b_loss: 1.3989 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.
- out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3889 - val_loss: 1.4126 - val_out_a_loss: 0.0017 - val_out_b_loss: 1.4110 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4110
# Epoch 139/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3911 - out_a_loss: 0.0023 - out_b_loss: 1.3888 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3888 - val_loss: 1.4129 - val_out_a_loss: 9.3486e-04 - val_out_b_loss: 1.4120 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4120
# Epoch 140/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3915 - out_a_loss: 0.0021 - out_b_loss: 1.3894 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3894 - val_loss: 1.4179 - val_out_a_loss: 0.0044 - val_out_b_loss: 1.4135 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4135
# Epoch 141/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3915 - out_a_loss: 0.0026 - out_b_loss: 1.3889 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3889 - val_loss: 1.4165 - val_out_a_loss: 4.6600e-04 - val_out_b_loss: 1.4160 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4160
# Epoch 142/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.3908 - out_a_loss: 0.0017 - out_b_loss: 1.3891 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3891 - val_loss: 1.4136 - val_out_a_loss: 0.0023 - val_out_b_loss: 1.4114 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4114
# Epoch 143/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3903 - out_a_loss: 0.0014 - out_b_loss: 1.3889 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3889 - val_loss: 1.4175 - val_out_a_loss: 0.0080 - val_out_b_loss: 1.4095 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4095
# Epoch 144/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3970 - out_a_loss: 0.0064 - out_b_loss: 1.3906 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3906 - val_loss: 1.4148 - val_out_a_loss: 0.0045 - val_out_b_loss: 1.4103 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4103
# Epoch 145/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3949 - out_a_loss: 0.0019 - out_b_loss: 1.3930 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3930 - val_loss: 1.4083 - val_out_a_loss: 0.0014 - val_out_b_loss: 1.4070 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4070
# Epoch 146/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.3906 - out_a_loss: 0.0013 - out_b_loss: 1.3893 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3893 - val_loss: 1.4137 - val_out_a_loss: 0.0019 - val_out_b_loss: 1.4118 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4118
# Epoch 147/200
# ...
# Epoch 153/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3963 - out_a_loss: 0.0030 - out_b_loss: 1.3933 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3933 - val_loss: 1.4352 - val_out_a_loss: 0.0213 - val_out_b_loss: 1.4139 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4139
# Epoch 154/200
# 1000/1000 [==============================] - 0s 102us/step - loss: 1.4126 - out_a_loss: 0.0132 - out_b_loss: 1.3994 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3994 - val_loss: 1.4373 - val_out_a_loss: 0.0101 - val_out_b_loss: 1.4272 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4272
# Epoch 155/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4002 - out_a_loss: 0.0056 - out_b_loss: 1.3946 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3946 - val_loss: 1.4303 - val_out_a_loss: 0.0045 - val_out_b_loss: 1.4258 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4258
# Epoch 156/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.4049 - out_a_loss: 0.0048 - out_b_loss: 1.4000 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.4000 - val_loss: 1.4250 - val_out_a_loss: 4.8592e-04 - val_out_b_loss: 1.4246 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4246
# Epoch 157/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3925 - out_a_loss: 0.0035 - out_b_loss: 1.3890 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3890 - val_loss: 1.4280 - val_out_a_loss: 4.6048e-04 - val_out_b_loss: 1.4275 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4275
# Epoch 158/200
# 1000/1000 [==============================] - ETA: 0s - loss: 1.3946 - out_a_loss: 0.0032 - out_b_loss: 1.3914 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3914   - 0s 99us/step - loss: 1.3936 - out_a_loss: 0.0032 - out_b_loss: 1.3904 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3904 - val_loss: 1.4264 - val_out_a_loss: 0.0012 - val_out_b_loss: 1.4252 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4252
# Epoch 159/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3950 - out_a_loss: 0.0029 - out_b_loss: 1.3922 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3922 - val_loss: 1.4231 - val_out_a_loss: 5.5064e-04 - val_out_b_loss: 1.4225 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4225
# Epoch 160/200
# 1000/1000 [==============================] - 0s 96us/step - loss: 1.3927 - out_a_loss: 0.0027 - out_b_loss: 1.3900 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3900 - val_loss: 1.4199 - val_out_a_loss: 0.0011 - val_out_b_loss: 1.4188 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4188
# Epoch 161/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.3927 - out_a_loss: 0.0022 - out_b_loss: 1.3905 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3905 - val_loss: 1.4211 - val_out_a_loss: 0.0033 - val_out_b_loss: 1.4177 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4177
# Epoch 162/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3905 - out_a_loss: 0.0015 - out_b_loss: 1.3890 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3890 - val_loss: 1.4096 - val_out_a_loss: 0.0052 - val_out_b_loss: 1.4044 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4044
# Epoch 163/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3932 - out_a_loss: 0.0031 - out_b_loss: 1.3901 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3901 - val_loss: 1.4122 - val_out_a_loss: 0.0044 - val_out_b_loss: 1.4078 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4078
# Epoch 164/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3947 - out_a_loss: 0.0023 - out_b_loss: 1.3924 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3924 - val_loss: 1.4170 - val_out_a_loss: 0.0071 - val_out_b_loss: 1.4099 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4099
# Epoch 165/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3958 - out_a_loss: 0.0040 - out_b_loss: 1.3918 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3918 - val_loss: 1.4178 - val_out_a_loss: 0.0069 - val_out_b_loss: 1.4109 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4109
# Epoch 166/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.3943 - out_a_loss: 0.0038 - out_b_loss: 1.3905 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3905 - val_loss: 1.4148 - val_out_a_loss: 7.7611e-04 - val_out_b_loss: 1.4140 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4140
# Epoch 167/200
# 1000/1000 [==============================] - 0s 104us/step - loss: 1.3910 - out_a_loss: 0.0020 - out_b_loss: 1.3890 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3890 - val_loss: 1.4207 - val_out_a_loss: 9.3425e-04 - val_out_b_loss: 1.4197 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4197
# Epoch 168/200
# 1000/1000 [==============================] - 0s 99us/step - loss: 1.3905 - out_a_loss: 0.0018 - out_b_loss: 1.3887 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3887 - val_loss: 1.4178 - val_out_a_loss: 0.0011 - val_out_b_loss: 1.4167 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4167
# Epoch 169/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3899 - out_a_loss: 0.0015 - out_b_loss: 1.3884 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3884 - val_loss: 1.4157 - val_out_a_loss: 0.0078 - val_out_b_loss: 1.4078 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4078
# Epoch 170/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.3914 - out_a_loss: 0.0029 - out_b_loss: 1.3885 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3885 - val_loss: 1.4136 - val_out_a_loss: 0.0013 - val_out_b_loss: 1.4123 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4123
# Epoch 171/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3898 - out_a_loss: 0.0015 - out_b_loss: 1.3883 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3883 - val_loss: 1.4117 - val_out_a_loss: 0.0021 - val_out_b_loss: 1.4097 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4097
# Epoch 172/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3899 - out_a_loss: 0.0011 - out_b_loss: 1.3887 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3887 - val_loss: 1.4155 - val_out_a_loss: 0.0033 - val_out_b_loss: 1.4122 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4122
# Epoch 173/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3959 - out_a_loss: 0.0036 - out_b_loss: 1.3923 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3923 - val_loss: 1.4141 - val_out_a_loss: 0.0116 - val_out_b_loss: 1.4025 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4025
# Epoch 174/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.4013 - out_a_loss: 0.0074 - out_b_loss: 1.3939 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3939 - val_loss: 1.4243 - val_out_a_loss: 0.0012 - val_out_b_loss: 1.4231 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4231
# Epoch 175/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.
- val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4296
# Epoch 191/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.3944 - out_a_loss: 0.0031 - out_b_loss: 1.3913 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3913 - val_loss: 1.4223 - val_out_a_loss: 3.3704e-04 - val_out_b_loss: 1.4219 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4219
# Epoch 192/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3923 - out_a_loss: 0.0026 - out_b_loss: 1.3897 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3897 - val_loss: 1.4299 - val_out_a_loss: 0.0038 - val_out_b_loss: 1.4261 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4261
# Epoch 193/200
# 1000/1000 [==============================] - 0s 96us/step - loss: 1.3952 - out_a_loss: 0.0030 - out_b_loss: 1.3922 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3922 - val_loss: 1.4251 - val_out_a_loss: 0.0037 - val_out_b_loss: 1.4213 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4213
# Epoch 194/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3947 - out_a_loss: 0.0029 - out_b_loss: 1.3918 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3918 - val_loss: 1.4240 - val_out_a_loss: 4.2365e-04 - val_out_b_loss: 1.4235 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4235
# Epoch 195/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3948 - out_a_loss: 0.0036 - out_b_loss: 1.3912 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3912 - val_loss: 1.4201 - val_out_a_loss: 0.0027 - val_out_b_loss: 1.4174 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4174
# Epoch 196/200
# 1000/1000 [==============================] - 0s 100us/step - loss: 1.3942 - out_a_loss: 0.0026 - out_b_loss: 1.3916 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3916 - val_loss: 1.4141 - val_out_a_loss: 0.0023 - val_out_b_loss: 1.4118 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4118
# Epoch 197/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3898 - out_a_loss: 0.0013 - out_b_loss: 1.3885 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3885 - val_loss: 1.4130 - val_out_a_loss: 8.6946e-04 - val_out_b_loss: 1.4122 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4122
# Epoch 198/200
# 1000/1000 [==============================] - 0s 97us/step - loss: 1.3879 - out_a_loss: 0.0012 - out_b_loss: 1.3867 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3867 - val_loss: 1.4184 - val_out_a_loss: 5.6306e-04 - val_out_b_loss: 1.4178 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4178
# Epoch 199/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3889 - out_a_loss: 0.0012 - out_b_loss: 1.3877 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3877 - val_loss: 1.4153 - val_out_a_loss: 6.8850e-04 - val_out_b_loss: 1.4146 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4146
# Epoch 200/200
# 1000/1000 [==============================] - 0s 98us/step - loss: 1.3907 - out_a_loss: 0.0020 - out_b_loss: 1.3887 - out_a_acc: 1.0000 - out_b_categorical_crossentropy: 1.3887 - val_loss: 1.4188 - val_out_a_loss: 0.0013 - val_out_b_loss: 1.4175 - val_out_a_acc: 1.0000 - val_out_b_categorical_crossentropy: 1.4175

# %%
# Plot input data

data = np.concatenate((classifier.data, classifier.data_out), axis=0)
labels = np.concatenate((classifier.labels, classifier.labels_out), axis=0)
fig = plt.figure()
plt.scatter(data[:, 0], data[:, 1], s=4, c=labels.squeeze())
# Out:
# <img src="data:image/png;base64,..." width="575">

# %%
# Plot classified data - for test data

X_test = np.concatenate((classifier.X_test, classifier.X_test_outliers), axis=0)
y_test = np.concatenate((classifier.y_test, classifier.y_test_outliers), axis=0)

y_pred = classifier.model.predict(X_test)
y_max = y_pred.max(axis = -1)
#plt.scatter(X_test[:, 0], X_test[:, 1], s=4, c=y_max.squeeze())

# Plot classified data - for test data

y_labels = y_pred.argmax(axis = -1)

fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax = Axes3D(fig)

#ax.scatter(X_test[:, 0], X_test[:, 1], y_max, c=y_test.squeeze())
plt.scatter(X_test[:, 0], X_test[:, 1], s=4, c=y_max.squeeze())
# Out:
# <img src="data:image/png;base64,..." width="575">

# %%
# Create image for paper
classifier.n = 400
data, labels, data_out, labels_out = classifier.get_data()
ind_0 = np.where(labels==0)[0][0:50]
ind_1 = np.where(labels==1)[0][0:50]
ind_2 = np.where(labels_out==2)[0]
ind = np.random.randint(0, ind_2.shape[0], 200)
ind_2 = ind_2[ind]
data = np.concatenate((data[ind_0,:], data[ind_1,:], data_out[ind_2,:]), axis=0)
labels = np.concatenate((labels[ind_0,:], labels[ind_1,:], labels_out[ind_2,:]), axis=0)
#data_outlier, labels_outlier = classifier.get_outlier_data()
#data = np.concatenate((data, data_outlier), axis=0)
#labels = np.concatenate((labels, labels_outlier))
print(data.shape)
print(labels.shape)
# Out:
# (400, 1)
# (800, 1)
# (800, 1)
# (300, 2)
# (300, 1)

# %%
y_pred = classifier.model.predict(data)
y_labels = y_pred.argmax(axis = -1)
y_max = y_pred.max(axis = -1)

ind = np.where(y_max <= 0.6)[0]
y_labels[ind] = 2

ind = np.where(y_max >= 0.6)[0]
y_labels[ind] = 0

ind = np.where(((y_max > 0.6) & (y_max < 0.9)))[0]
y_labels[ind] = 1


c_list = ['r', 'b', 'y']
marker_list = ['D', 'o', '*']
plt.figure(figsize=(5,5))
for i in range(0, data.shape[0]):
    marker = marker_list[int(labels[i])]
    c = c_list[y_labels[i]]
    plt.scatter(data[i, 0], data[i, 1], s=10, c=c, marker=marker)

plt.legend(('$class\ 0$','$class\ 1$','$OOD\ sample$'), fontsize='x-small');
import matplotlib.lines as lines
dimond_line = lines.Line2D([0], [0], color='w', marker='D', markerfacecolor='g',
                          markersize=5, label='TC 0')

circle_line = lines.Line2D([0], [0], marker='o', color='w', label='TC 1',
                          markerfacecolor='g', markersize=5)

star_line = lines.Line2D([0], [0], color='w', marker='*', markerfacecolor='g',
                          markersize=10, label='TC 2')


red_line = lines.Line2D([0], [0], marker='s', color='w', label='[0.9, 1]',
                          markerfacecolor='r', markersize=5)


blue_line = lines.Line2D([0], [0], marker='s', color='w', label='(0.6, 0.9)',
                          markerfacecolor='b', markersize=5)


yellow_line = lines.Line2D([0], [0], marker='s', color='w', label='[0.5, 0.6]',
                          markerfacecolor='y', markersize=5)

# Create a legend for the first line.
first_legend = plt.legend(handles=[dimond_line, circle_line, star_line], loc=1)


# Add the legend manually to the current Axes.
ax = plt.gca().add_artist(first_legend)

# Create another legend for the second line.
plt.legend(handles=[red_line, blue_line, yellow_line], loc=4)

plt.show()
plt.savefig("exp2_b")
# Out:
# <img src="data:image/png;base64,..." width="449">

# %%
print(y_max.shape)
print(np.where(y_max>0.95)[0].shape)
print(np.where(y_max<0.55)[0].shape)
# Out:
# (2000,)
# (1004,)
# (986,)

# %%
np.unique(y_test)
# Out:
# array([0., 1., 2.], dtype=float32)

# %%
print(np.where(y_test==0)[0].shape)
# Out:
# (500,)
